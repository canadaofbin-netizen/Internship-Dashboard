# %% [markdown]
# ## Data Filtering and Selection

# %%
# !pip install --upgrade pip 
# !pip install pandas
# Out:
# Requirement already satisfied: pip in C:\Users\yunky\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (26.2.1)
# Requirement already satisfied: pandas in C:\Users\yunky\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\yunky\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\yunky\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\yunky\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\yunky\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# #### Comparison operators (> < = <= => == !=) and Masking.

# %%
import numpy as np
import pandas as pd 

from pandas import DataFrame

# %%
numbers_df = DataFrame(np.arange(0, 90, 3).reshape(10, 3))
numbers_df
# Out:
#     0   1   2
# 0   0   3   6
# 1   9  12  15
# 2  18  21  24
# 3  27  30  33
# 4  36  39  42
# 5  45  48  51
# 6  54  57  60
# 7  63  66  69
# 8  72  75  78
# 9  81  84  87
